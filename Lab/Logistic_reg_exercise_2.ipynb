# %% [markdown]
# # Exercise: Movie Dataset
#
# You are provided with a dataset containing information about movies, including their marketing expenses, production expenses, multiplex coverage, budget, movie length, ratings of lead actors, lead actresses, directors, and producers, critic ratings, trailer views, 3D availability, time taken for production, Twitter hashtags, genre, average age of actors, number of multiplexes, collections, and whether the movie started a technical Oscar nomination or not. This dataset offers valuable insights into the factors contributing to a movie's success and its chances of receiving a technical Oscar nomination. Analyzing the patterns in this dataset can help stakeholders in the movie industry make better-informed decisions regarding movie production, promotion, and targeting specific audience demographics.
#
# ## Dataset Description
#
# The dataset (506x19) comprises eighteen columns as follows:
#
# - Marketing expense: The cost of marketing the movie
#
# - Production expense: The cost incurred during the production of the movie
#
# - Multiplex coverage: The proportion of multiplexes showing the movie
#
# - Budget: The movie's production budget
#
# - Movie_length: The length of the movie in minutes
#
# - Lead_ Actor_Rating: Rating of the lead actor
#
# - Lead_Actress_rating: Rating of the lead actress
#
# - Director_rating: Rating of the movie director
#
# - Producer_rating: Rating of the movie producer
#
# - Critic_rating: Rating given by movie critics
#
# - Trailer_views: The number of views of the movie's trailer
#
# - 3D_available: Whether the movie is available in 3D (YES/NO)
#
# - Time_taken: Time taken for the movie's production in days
#
# - Twitter_hastags: The number of Twitter hashtags related to the movie
#
# - Genre: The genre of the movie (Action, Comedy, Drama, Thriller, etc.)
#
# - Avg_age_actors: The average age of the actors in the movie
#
# - Num_multiplex: The number of multiplexes where the movie is being shown
#
# - Collection: The total box office collection of the movie
#
# - Start_Tech_Oscar: Whether the movie started a technical Oscar nomination (1 for yes, 0 for no). This column serves as the output label, while the remaining columns are input features.
#
# <br><br>
# **Now, you are requried to import sklearn library and build a Logistic Regression model for this classification task.**
# - Start_Tech_Oscar is the <u>output label</u>
# - The rest columns are the <u>input features</u>.
#
# <br>
# At a minimum, you should include steps such as simple Data Exploration/Visualization, Data Pre-processing including Normalization, Model Building, Model Evaluation, and Making Predictions with the Model.

# %% [markdown]
# ---

# %% [markdown]
# ## Step 1: Import Library

# %% [markdown]
# ## Step 2: Read the Data

# %% [markdown]
# Load dataset and do some basic exploration to understand the shape/structure, data types, and summary statistics of the data.

# %% [markdown]
# ## Step 3: Data Exploration/Visualization
#
# Perform exploratory data analysis (EDA) to understand the distribution of features and their relationships with the target variable. Use visualizations such as histograms, box plots, scatter plots, and correlation matrices to identify patterns in the data.
#
# If unsure about how or what to visualize, refer to lecture notes.

# %% [markdown]
# ## Step 4: Data Preprocessing
# Prepare the data for modeling by handling missing values, encoding categorical variables, and normalizing numerical features.

# %%
# Impute missing values if any

# %% [markdown]
# For rest of the preprocessing steps, you can follow this guide:
# 1. Separate features and target, then do train-test split
# 2. Scaling/normalization (use `StandardScaler`) on the numerical features. Scale only the training data and apply the same transformation to the test data.
# 3. One-hot encode categorical features (use `OneHotEncoder` in sklearn). Fit the encoder on the training data and transform both training and test data.

# %% [markdown]
# ## Step 5: Model Building and Evaluation
# Build a Logistic Regression model using the preprocessed data. Finally, evaluate the model's performance using appropriate metrics for both training and testing datasets.
